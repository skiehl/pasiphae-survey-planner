# %% [markdown]
# # Test database queries

# %% [markdown]
# **Goal of this notebook:** The original implementation of the `FieldManager.get_fields()` method in `db.py` was unbarebly slow. Here I am testing why and how to fix it.

# %%
from pandas import DataFrame
import timeit

from db import SQLiteConnection

# %%
db_file = 'test_strategy.sqlite3'

# %% [markdown]
# ## Query `Fields` table

# %%
def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM Fields
        """
        results = cursor.execute(query).fetchall()
    return results

# %%
DataFrame(query())
# Out:
#         field_id       fov  center_ra  center_dec  tilt  telescope_id  active
# 0              1  0.008727   0.000000    0.004363   0.0             1       1
# 1              2  0.008727   0.008678    0.004363   0.0             1       1
# 2              3  0.008727   0.017357    0.004363   0.0             1       1
# 3              4  0.008727   0.026035    0.004363   0.0             1       1
# 4              5  0.008727   0.034714    0.004363   0.0             1       1
# ...          ...       ...        ...         ...   ...           ...     ...
# 145310    145311  0.010181   6.232514   -0.004000   0.0             2       1
# 145311    145312  0.010181   6.242649   -0.004000   0.0             2       1
# 145312    145313  0.010181   6.252783   -0.004000   0.0             2       1
# 145313    145314  0.010181   6.262917   -0.004000   0.0             2       1
# 145314    145315  0.010181   6.273051   -0.004000   0.0             2       1
#
# [145315 rows x 7 columns]

# %% [markdown]
# Run time:

# %%
rep = 10
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 0.467 s

# %% [markdown]
# ## Query `FieldsObs` view

# %%
def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs
        """
        results = cursor.execute(query).fetchall()
    return results

# %%
DataFrame(query())
# Out:
#         field_id       fov  center_ra  center_dec  tilt telescope  active  \
# 0              1  0.008727   0.000000    0.004363   0.0  Skinakas       1
# 1              2  0.008727   0.008678    0.004363   0.0  Skinakas       1
# 2              3  0.008727   0.017357    0.004363   0.0  Skinakas       1
# 3              4  0.008727   0.026035    0.004363   0.0  Skinakas       1
# 4              5  0.008727   0.034714    0.004363   0.0  Skinakas       1
# ...          ...       ...        ...         ...   ...       ...     ...
# 145310    145311  0.010181   6.232514   -0.004000   0.0      SAAO       1
# 145311    145312  0.010181   6.242649   -0.004000   0.0      SAAO       1
# 145312    145313  0.010181   6.252783   -0.004000   0.0      SAAO       1
# 145313    145314  0.010181   6.262917   -0.004000   0.0      SAAO       1
# 145314    145315  0.010181   6.273051   -0.004000   0.0      SAAO       1
#
#          jd_first    jd_next  nobs_tot  nobs_done  nobs_pending
# 0       2460310.5  2460370.5         1          0             1
# 1       2460310.5  2460370.5         1          0             1
# 2       2460310.5  2460370.5         1          0             1
# 3       2460310.5  2460370.5         1          0             1
# 4       2460310.5  2460370.5         1          0             1
# ...           ...        ...       ...        ...           ...
# 145310  2460310.5  2460370.5         1          0             1
# 145311  2460310.5  2460370.5         1          0             1
# 145312  2460310.5  2460370.5         1          0             1
# 145313  2460310.5  2460370.5         1          0             1
# 145314  2460310.5  2460370.5         1          0             1
#
# [145315 rows x 12 columns]

# %% [markdown]
# Run time:

# %%
rep = 20
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 0.971 s

# %% [markdown]
# ### Conditional search for fields with pending observations

# %%
def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs
                WHERE nobs_pending > 0
        """
        results = cursor.execute(query).fetchall()
    return results

# %%
DataFrame(query())
# Out:
#         field_id       fov  center_ra  center_dec  tilt telescope  active  \
# 0              1  0.008727   0.000000    0.004363   0.0  Skinakas       1
# 1              2  0.008727   0.008678    0.004363   0.0  Skinakas       1
# 2              3  0.008727   0.017357    0.004363   0.0  Skinakas       1
# 3              4  0.008727   0.026035    0.004363   0.0  Skinakas       1
# 4              5  0.008727   0.034714    0.004363   0.0  Skinakas       1
# ...          ...       ...        ...         ...   ...       ...     ...
# 145310    145311  0.010181   6.232514   -0.004000   0.0      SAAO       1
# 145311    145312  0.010181   6.242649   -0.004000   0.0      SAAO       1
# 145312    145313  0.010181   6.252783   -0.004000   0.0      SAAO       1
# 145313    145314  0.010181   6.262917   -0.004000   0.0      SAAO       1
# 145314    145315  0.010181   6.273051   -0.004000   0.0      SAAO       1
#
#          jd_first    jd_next  nobs_tot  nobs_done  nobs_pending
# 0       2460310.5  2460370.5         1          0             1
# 1       2460310.5  2460370.5         1          0             1
# 2       2460310.5  2460370.5         1          0             1
# 3       2460310.5  2460370.5         1          0             1
# 4       2460310.5  2460370.5         1          0             1
# ...           ...        ...       ...        ...           ...
# 145310  2460310.5  2460370.5         1          0             1
# 145311  2460310.5  2460370.5         1          0             1
# 145312  2460310.5  2460370.5         1          0             1
# 145313  2460310.5  2460370.5         1          0             1
# 145314  2460310.5  2460370.5         1          0             1
#
# [145315 rows x 12 columns]

# %% [markdown]
# Run time:

# %%
rep = 20
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 0.920 s

# %% [markdown]
# ## Query `Observable` view

# %% [markdown]
# **Note:** We cannot query the entire table which contains millions of rows. We perform a typical query for fields observable during a specific night:

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM Observable
                WHERE (
                    date_start < '{0}'
                    AND date_stop > '{1}'
                    )
        """.format(night_stop, night_start)
        results = cursor.execute(query).fetchall()
    return results

# %%
DataFrame(query())
# Out:
#        field_id               date_start                date_stop  duration  \
# 0          2094  2024-01-16 01:06:00.000  2024-01-16 04:29:36.381  0.141393
# 1          2095  2024-01-16 01:08:00.000  2024-01-16 04:29:36.381  0.140004
# 2          2096  2024-01-16 01:10:00.000  2024-01-16 04:29:36.381  0.138616
# 3          2097  2024-01-16 01:12:00.000  2024-01-16 04:29:36.381  0.137227
# 4          2098  2024-01-16 01:14:00.000  2024-01-16 04:29:36.381  0.135838
# ...         ...                      ...                      ...       ...
# 80796    145184  2024-01-16 02:33:00.000  2024-01-16 02:44:07.656  0.007728
# 80797    145185  2024-01-16 02:35:00.000  2024-01-16 02:44:07.656  0.006339
# 80798    145186  2024-01-16 02:38:00.000  2024-01-16 02:44:07.656  0.004255
# 80799    145188  2024-01-16 02:42:00.000  2024-01-16 02:50:00.000  0.005556
# 80800    145189  2024-01-16 02:44:07.656  2024-01-16 02:50:00.000  0.004078
#
#        status  setting_duration
# 0      rising               NaN
# 1      rising               NaN
# 2      rising               NaN
# 3      rising               NaN
# 4      rising               NaN
# ...       ...               ...
# 80796  rising               NaN
# 80797  rising               NaN
# 80798  rising               NaN
# 80799  rising               NaN
# 80800  rising               NaN
#
# [80801 rows x 6 columns]

# %% [markdown]
# Run time:

# %%
rep = 10
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 2.469 s

# %% [markdown]
# ## Joint query of `FieldsObs` and `Observable` view

# %% [markdown]
# **Note:** We cannot query the entire table which contains millions of rows. We perform a query for fields observable during a specific night, which is the typical usecase.

# %% [markdown]
# ### No additional conditions

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs AS f
                INNER JOIN Observable AS o
                ON f.field_id = o.field_id
                WHERE (
                    o.date_start < '{0}'
                    AND o.date_stop > '{1}'
                    )
        """.format(night_stop, night_start)
        results = cursor.execute(query).fetchall()
    return results

# %%
DataFrame(query())
# Out:
#        field_id       fov  center_ra  center_dec  tilt telescope  active  \
# 0          2094  0.008727   3.653620    0.021817   0.0  Skinakas       1
# 1          2095  0.008727   3.662299    0.021817   0.0  Skinakas       1
# 2          2096  0.008727   3.670977    0.021817   0.0  Skinakas       1
# 3          2097  0.008727   3.679655    0.021817   0.0  Skinakas       1
# 4          2098  0.008727   3.688334    0.021817   0.0  Skinakas       1
# ...         ...       ...        ...         ...   ...       ...     ...
# 80796    145184  0.010181   3.769911   -0.004000   0.0      SAAO       1
# 80797    145185  0.010181   3.780045   -0.004000   0.0      SAAO       1
# 80798    145186  0.010181   3.790180   -0.004000   0.0      SAAO       1
# 80799    145188  0.010181   3.810448   -0.004000   0.0      SAAO       1
# 80800    145189  0.010181   3.820582   -0.004000   0.0      SAAO       1
#
#         jd_first    jd_next  nobs_tot  nobs_done  nobs_pending  \
# 0      2460310.5  2460370.5         1          0             1
# 1      2460310.5  2460370.5         1          0             1
# 2      2460310.5  2460370.5         1          0             1
# 3      2460310.5  2460370.5         1          0             1
# 4      2460310.5  2460370.5         1          0             1
# ...          ...        ...       ...        ...           ...
# 80796  2460310.5  2460370.5         1          0             1
# 80797  2460310.5  2460370.5         1          0             1
# 80798  2460310.5  2460370.5         1          0             1
# 80799  2460310.5  2460370.5         1          0             1
# 80800  2460310.5  2460370.5         1          0             1
#
#                     date_start                date_stop  duration  status  \
# 0      2024-01-16 01:06:00.000  2024-01-16 04:29:36.381  0.141393  rising
# 1      2024-01-16 01:08:00.000  2024-01-16 04:29:36.381  0.140004  rising
# 2      2024-01-16 01:10:00.000  2024-01-16 04:29:36.381  0.138616  rising
# 3      2024-01-16 01:12:00.000  2024-01-16 04:29:36.381  0.137227  rising
# 4      2024-01-16 01:14:00.000  2024-01-16 04:29:36.381  0.135838  rising
# ...                        ...                      ...       ...     ...
# 80796  2024-01-16 02:33:00.000  2024-01-16 02:44:07.656  0.007728  rising
# 80797  2024-01-16 02:35:00.000  2024-01-16 02:44:07.656  0.006339  rising
# 80798  2024-01-16 02:38:00.000  2024-01-16 02:44:07.656  0.004255  rising
# 80799  2024-01-16 02:42:00.000  2024-01-16 02:50:00.000  0.005556  rising
# 80800  2024-01-16 02:44:07.656  2024-01-16 02:50:00.000  0.004078  rising
#
#        setting_duration
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 80796               NaN
# 80797               NaN
# 80798               NaN
# 80799               NaN
# 80800               NaN
#
# [80801 rows x 17 columns]

# %% [markdown]
# Run time:

# %%
rep = 10
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 2.503 s

# %% [markdown]
# ### Query only active fields associated with specific telescope

# %% [markdown]
# **Note:** This takes very long, when we try to fetch all results. For a quicker test, we only fetch the first row.

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'
telescope = 'Skinakas'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs AS f
                INNER JOIN Observable AS o
                ON f.field_id = o.field_id
                WHERE (
                    o.date_start < '{0}'
                    AND o.date_stop > '{1}'
                    AND f.telescope = '{2}'
                    AND f.active = 1
                    )
        """.format(night_stop, night_start, telescope)
        results = cursor.execute(query).fetchone()
    return results

# %%
rep = 10
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 0.454 s

# %% [markdown]
# ### Query only active fields with pending observations and associated with specific telescope

# %% [markdown]
# **Note:** This takes very long, when we try to fetch all results. For a quicker test, we only fetch the first row.

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'
telescope = 'Skinakas'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs AS f
                INNER JOIN Observable AS o
                ON f.field_id = o.field_id
                WHERE (
                    o.date_start < '{0}'
                    AND o.date_stop > '{1}'
                    AND telescope = '{2}'
                    AND f.active = 1
                    AND f.nobs_pending > 0
                    )
        """.format(night_stop, night_start, telescope)
        results = cursor.execute(query).fetchone()
    return results

# %%
rep = 5
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 13.020 s

# %% [markdown]
# #### Conditional FieldsObs before join

# %% [markdown]
# **Note:** This takes very long, when we try to fetch all results. For a quicker test and comparability to the test above, we only fetch the first row.

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'
telescope = 'Skinakas'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM (
                    SELECT *
                    FROM FieldsObs
                    WHERE (
                        active = 1
                        AND telescope = '{2}'
                        AND nobs_pending > 0
                        )
                    ) AS f
                INNER JOIN Observable AS o
                ON f.field_id = o.field_id
                WHERE (
                    o.date_start < '{0}'
                    AND o.date_stop > '{1}'
                    )
        """.format(night_stop, night_start, telescope)
        results = cursor.execute(query).fetchone()
    return results

# %%
rep = 5
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 12.171 s

# %% [markdown]
# **Result:** Does not provide a substantial runtime improvement.

# %% [markdown]
# #### Conditional Observable before join

# %% [markdown]
# **Note:** This takes very long, when we try to fetch all results. For a quicker test and comparability to the test above, we only fetch the first row.

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'
telescope = 'Skinakas'

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs AS f
                INNER JOIN (
                    SELECT *
                    FROM Observable 
                    WHERE (
                        date_start < '{0}'
                        AND date_stop > '{1}'
                        )
                    ) AS o
                ON f.field_id = o.field_id
                WHERE (
                    f.telescope = '{2}'
                    AND f.active = 1
                    AND f.nobs_pending > 0
                    )
        """.format(night_stop, night_start, telescope)
        results = cursor.execute(query).fetchone()
    return results

# %%
rep = 5
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 12.440 s

# %% [markdown]
# **Result:** Does not provide a substantial runtime improvement.

# %% [markdown]
# ### Apply additional conditions in python

# %%
night_start = '2024-01-15 23:00:00'
night_stop = '2024-01-16 04:00:00'
telescope = 'Skinakas'
observed = None
pending = True
active = True

def query():
    with SQLiteConnection(db_file) as connection:
        cursor = connection.cursor()
        query = """\
                SELECT *
                FROM FieldsObs AS f
                INNER JOIN Observable AS o
                ON f.field_id = o.field_id
                WHERE (
                    o.date_start < '{0}'
                    AND o.date_stop > '{1}'
                    )
        """.format(night_stop, night_start)
        results_temp = cursor.execute(query).fetchall()
        results = []
        
        # apply additional conditions:
        for __ in range(len(results_temp)):
            keep = True
            result = results_temp.pop(0)
            
            # condition: telescope:
            if telescope is None:
                pass
            elif telescope != result['telescope']:
                keep = False
            
            # condition: pending or not:
            if pending is None:
                pass
            elif pending and result['nobs_pending'] == 0:
                keep = False
            elif not pending and result['nobs_pending'] > 0:
                keep = False
            
            # condition: active or not:
            if active is None:
                pass
            elif active and not result['active']:
                keep = False
            elif not active and result['active']:
                keep = False
            
            if keep:
                results.append(result)
            
    return results

# %%
DataFrame(query())
# Out:
#        field_id       fov  center_ra  center_dec  tilt telescope  active  \
# 0          2094  0.008727   3.653620    0.021817   0.0  Skinakas       1
# 1          2095  0.008727   3.662299    0.021817   0.0  Skinakas       1
# 2          2096  0.008727   3.670977    0.021817   0.0  Skinakas       1
# 3          2097  0.008727   3.679655    0.021817   0.0  Skinakas       1
# 4          2098  0.008727   3.688334    0.021817   0.0  Skinakas       1
# ...         ...       ...        ...         ...   ...       ...     ...
# 63317     81623  0.008727   2.219604    1.317724   0.0  Skinakas       1
# 63318     81624  0.008727   2.253751    1.317724   0.0  Skinakas       1
# 63319     81625  0.008727   2.287899    1.317724   0.0  Skinakas       1
# 63320     81626  0.008727   2.322047    1.317724   0.0  Skinakas       1
# 63321     81627  0.008727   2.356194    1.317724   0.0  Skinakas       1
#
#         jd_first    jd_next  nobs_tot  nobs_done  nobs_pending  \
# 0      2460310.5  2460370.5         1          0             1
# 1      2460310.5  2460370.5         1          0             1
# 2      2460310.5  2460370.5         1          0             1
# 3      2460310.5  2460370.5         1          0             1
# 4      2460310.5  2460370.5         1          0             1
# ...          ...        ...       ...        ...           ...
# 63317  2460310.5  2460370.5         1          0             1
# 63318  2460310.5  2460370.5         1          0             1
# 63319  2460310.5  2460370.5         1          0             1
# 63320  2460310.5  2460370.5         1          0             1
# 63321  2460310.5  2460370.5         1          0             1
#
#                     date_start                date_stop  duration  status  \
# 0      2024-01-16 01:06:00.000  2024-01-16 04:29:36.381  0.141393  rising
# 1      2024-01-16 01:08:00.000  2024-01-16 04:29:36.381  0.140004  rising
# 2      2024-01-16 01:10:00.000  2024-01-16 04:29:36.381  0.138616  rising
# 3      2024-01-16 01:12:00.000  2024-01-16 04:29:36.381  0.137227  rising
# 4      2024-01-16 01:14:00.000  2024-01-16 04:29:36.381  0.135838  rising
# ...                        ...                      ...       ...     ...
# 63317  2024-01-15 17:51:00.000  2024-01-16 04:28:00.000  0.442361  rising
# 63318  2024-01-15 17:59:00.000  2024-01-16 04:29:36.381  0.437921  rising
# 63319  2024-01-15 18:07:00.000  2024-01-16 04:29:36.381  0.432366  rising
# 63320  2024-01-15 18:14:00.000  2024-01-16 04:29:36.381  0.427504  rising
# 63321  2024-01-15 18:22:00.000  2024-01-16 04:29:36.381  0.421949  rising
#
#       setting_duration
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# ...                ...
# 63317             None
# 63318             None
# 63319             None
# 63320             None
# 63321             None
#
# [63322 rows x 17 columns]

# %%
rep = 10
runtime = timeit.timeit(query, number=rep) / rep
print(f'Runtime: {runtime:.3f} s')
# Out:
# Runtime: 3.226 s

# %% [markdown]
# **Result:**
# 1. This python post-filtering approach is faster than the SQL query with all conditions. Note that we are comparing fetching all rows in the last test and fetching only the first row in the plain-SQL test.
# 2. The post-filtering only increases the runtime by around 1 second, relative to the test case further above that did not apply the "pending" and "active" conditions.
# 3. This is a very feasible approach.
